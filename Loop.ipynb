# %%
library(RSQLite)
library(readr)
library(foreach)

conn <- dbConnect(RSQLite::SQLite(), "CoronaDB.db")

dates <- seq(as.Date("01-22-2020", "%m-%d-%Y"), as.Date("04-15-2020", "%m-%d-%Y"), by = 1)
dates <- format(dates, format = "%m-%d-%Y")
names <- as.character(dates)

foreach(d = dates, i = names) %do% {
    file = paste0("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/", d, ".csv")
    data <- read_csv(url(file))
    dbWriteTable(conn, i, data)
    }

dbDisconnect(conn)
# Out:
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_character(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   `Province/State` = col_character(),
#   `Country/Region` = col_character(),
#   `Last Update` = col_datetime(format = ""),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Latitude = col_double(),
#   Longitude = col_double()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_character(),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_character(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
#
# Parsed with column specification:
# cols(
#   FIPS = col_double(),
#   Admin2 = col_character(),
#   Province_State = col_character(),
#   Country_Region = col_character(),
#   Last_Update = col_datetime(format = ""),
#   Lat = col_double(),
#   Long_ = col_double(),
#   Confirmed = col_double(),
#   Deaths = col_double(),
#   Recovered = col_double(),
#   Active = col_double(),
#   Combined_Key = col_character()
# )
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE
#
# [[8]]
# [1] TRUE
#
# [[9]]
# [1] TRUE
#
# [[10]]
# [1] TRUE
#
# [[11]]
# [1] TRUE
#
# [[12]]
# [1] TRUE
#
# [[13]]
# [1] TRUE
#
# [[14]]
# [1] TRUE
#
# [[15]]
# [1] TRUE
#
# [[16]]
# [1] TRUE
#
# [[17]]
# [1] TRUE
#
# [[18]]
# [1] TRUE
#
# [[19]]
# [1] TRUE
#
# [[20]]
# [1] TRUE
#
# [[21]]
# [1] TRUE
#
# [[22]]
# [1] TRUE
#
# [[23]]
# [1] TRUE
#
# [[24]]
# [1] TRUE
#
# [[25]]
# [1] TRUE
#
# [[26]]
# [1] TRUE
#
# [[27]]
# [1] TRUE
#
# [[28]]
# [1] TRUE
#
# [[29]]
# [1] TRUE
#
# [[30]]
# [1] TRUE
#
# [[31]]
# [1] TRUE
#
# [[32]]
# [1] TRUE
#
# [[33]]
# [1] TRUE
#
# [[34]]
# [1] TRUE
#
# [[35]]
# [1] TRUE
#
# [[36]]
# [1] TRUE
#
# [[37]]
# [1] TRUE
#
# [[38]]
# [1] TRUE
#
# [[39]]
# [1] TRUE
#
# [[40]]
# [1] TRUE
#
# [[41]]
# [1] TRUE
#
# [[42]]
# [1] TRUE
#
# [[43]]
# [1] TRUE
#
# [[44]]
# [1] TRUE
#
# [[45]]
# [1] TRUE
#
# [[46]]
# [1] TRUE
#
# [[47]]
# [1] TRUE
#
# [[48]]
# [1] TRUE
#
# [[49]]
# [1] TRUE
#
# [[50]]
# [1] TRUE
#
# [[51]]
# [1] TRUE
#
# [[52]]
# [1] TRUE
#
# [[53]]
# [1] TRUE
#
# [[54]]
# [1] TRUE
#
# [[55]]
# [1] TRUE
#
# [[56]]
# [1] TRUE
#
# [[57]]
# [1] TRUE
#
# [[58]]
# [1] TRUE
#
# [[59]]
# [1] TRUE
#
# [[60]]
# [1] TRUE
#
# [[61]]
# [1] TRUE
#
# [[62]]
# [1] TRUE
#
# [[63]]
# [1] TRUE
#
# [[64]]
# [1] TRUE
#
# [[65]]
# [1] TRUE
#
# [[66]]
# [1] TRUE
#
# [[67]]
# [1] TRUE
#
# [[68]]
# [1] TRUE
#
# [[69]]
# [1] TRUE
#
# [[70]]
# [1] TRUE
#
# [[71]]
# [1] TRUE
#
# [[72]]
# [1] TRUE
#
# [[73]]
# [1] TRUE
#
# [[74]]
# [1] TRUE
#
# [[75]]
# [1] TRUE
#
# [[76]]
# [1] TRUE
#
# [[77]]
# [1] TRUE
#
# [[78]]
# [1] TRUE
#
# [[79]]
# [1] TRUE
#
# [[80]]
# [1] TRUE
#
# [[81]]
# [1] TRUE
#
# [[82]]
# [1] TRUE
#
# [[83]]
# [1] TRUE
#
# [[84]]
# [1] TRUE
#
# [[85]]
# [1] TRUE

# %%
dbGetQuery(conn, "SELECT * FROM [03-09-2020]")
# Out:
#     FIPS Admin2 Province_State                       Country_Region Last_Update
# 1   NA   NA     Hubei                                Mainland China 1583764383
# 2   NA   NA     NA                                   Italy          1583777591
# 3   NA   NA     NA                                   South Korea    1583744583
# 4   NA   NA     NA                                   Iran           1583751183
# 5   NA   NA     Guangdong                            Mainland China 1583718181
# 6   NA   NA     Henan                                Mainland China 1583643782
# 7   NA   NA     Zhejiang                             Mainland China 1583746983
# 8   NA   NA     NA                                   France         1583714583
# 9   NA   NA     NA                                   Germany        1583777591
# 10  NA   NA     NA                                   Spain          1583777591
# 11  NA   NA     Hunan                                Mainland China 1583717586
# 12  NA   NA     Anhui                                Mainland China 1583644386
# 13  NA   NA     Jiangxi                              Mainland China 1583718781
# 14  NA   NA     Shandong                             Mainland China 1583748786
# 15  NA   NA     Diamond Princess cruise ship         Others         1583458179
# 16  NA   NA     Jiangsu                              Mainland China 1583743983
# 17  NA   NA     Chongqing                            Mainland China 1583795583
# 18  NA   NA     Sichuan                              Mainland China 1583743983
# 19  NA   NA     NA                                   Japan          1583745197
# 20  NA   NA     Heilongjiang                         Mainland China 1583764383
# 21  NA   NA     Beijing                              Mainland China 1583718781
# 22  NA   NA     NA                                   Switzerland    1583753590
# 23  NA   NA     Shanghai                             Mainland China 1583726591
# 24  NA   NA     NA                                   Netherlands    1583777591
# 25  NA   NA     NA                                   UK             1583778783
# 26  NA   NA     Hebei                                Mainland China 1583586185
# 27  NA   NA     Fujian                               Mainland China 1583586185
# 28  NA   NA     Guangxi                              Mainland China 1583713389
# 29  NA   NA     NA                                   Sweden         1583778783
# 30  NA   NA     Shaanxi                              Mainland China 1583678583
# ... ...  ...    ...                                  ...            ...
# 237 NA   NA     Polk County, GA                      US             1583640802
# 238 NA   NA     Ramsey County, MN                    US             1583536983
# 239 NA   NA     Riverside County, CA                 US             1583663583
# 240 NA   NA     Rockingham County, NH                US             1583793805
# 241 NA   NA     San Antonio, TX                      US             1581619982
# 242 NA   NA     Santa Rosa County, FL                US             1583681584
# 243 NA   NA     Sarasota, FL                         US             1583119386
# 244 NA   NA     Shasta County, CA                    US             1583725383
# 245 NA   NA     Shelby County, TN                    US             1583684016
# 246 NA   NA     Spartanburg County, SC               US             1583712187
# 247 NA   NA     Spokane County, WA                   US             1583704384
# 248 NA   NA     St. Louis County, MO                 US             1583666588
# 249 NA   NA     Suffolk County, NY                   US             1583683385
# 250 NA   NA     Tulsa County, OK                     US             1583556182
# 251 NA   NA     Ulster County, NY                    US             1583684587
# 252 NA   NA     Umatilla, OR                         US             1583180596
# 253 NA   NA     Unknown Location, MA                 US             1583702583
# 254 NA   NA     Volusia County, FL                   US             1583636588
# 255 NA   NA     Wake County, NC                      US             1583268782
# 256 NA   NA     Wayne County, PA                     US             1583511195
# 257 NA   NA     Williamson County, TN                US             1583451183
# 258 NA   NA     Yolo County, CA                      US             1583525594
# 259 NA   NA     NA                                   Ukraine        1583249582
# 260 NA   NA     NA                                   Vatican City   1583509382
# 261 NA   NA     From Diamond Princess                Australia      1582941790
# 262 NA   NA     Northern Territory                   Australia      1583469183
# 263 NA   NA     Lackland, TX (From Diamond Princess) US             1582587182
# 264 NA   NA     Montgomery County, TX                US             1583610782
# 265 NA   NA     Omaha, NE (From Diamond Princess)    US             1582587182
# 266 NA   NA     Travis, CA (From Diamond Princess)   US             1582587182
#     Lat      Long_     Confirmed Deaths Recovered Active
# 1   30.9756  112.2707  67743     3008   46488     1461
# 2   43.0000   12.0000   9172      463     724       NA
# 3   36.0000  128.0000   7478       53     118       NA
# 4   32.0000   53.0000   7161      237    2394       NA
# 5   23.3417  113.4244   1352        8    1260      130
# 6   33.8820  113.6140   1272       22    1247        3
# 7   29.1832  120.0934   1215        1    1176       30
# 8   47.0000    2.0000   1209       19      12       NA
# 9   51.0000    9.0000   1176        2      18       NA
# 10  40.0000   -4.0000   1073       28      32       NA
# 11  27.6104  111.7088   1018        4     979        0
# 12  31.8257  117.2264    990        6     984        0
# 13  27.6140  115.7221    935        1     923        1
# 14  36.3427  118.1498    758        6     700       14
# 15  35.4437  139.6380    696        6      40       NA
# 16  32.9711  119.4550    631        0     621       15
# 17  30.0572  107.8740    576        6     542        3
# 18  30.6171  102.7103    539        3     466       11
# 19  36.0000  138.0000    511       17      76       NA
# 20  47.8620  127.7615    481       13     430        2
# 21  40.1824  116.4142    428        8     315      154
# 22  46.8182    8.2275    374        2       3       NA
# 23  31.2020  121.4491    342        3     315      163
# 24  52.1326    5.2913    321        3       0       NA
# 25  55.0000   -3.0000    321        4      18       NA
# 26  38.0428  114.5149    318        6     307        5
# 27  26.0789  117.9874    296        1     295       47
# 28  23.8298  108.7881    252        2     230        2
# 29  63.0000   16.0000    248        0       1       NA
# 30  35.1917  108.8701    245        1     227        8
# ... ...      ...       ...       ...    ...       ...
# 237  34.0132  -85.1479 1         0      0         NA
# 238  44.9964  -93.0616 1         0      0         NA
# 239  33.9533 -117.3961 1         0      0         NA
# 240  42.9931  -71.0498 1         0      0         NA
# 241  29.4241  -98.4936 1         0      0         NA
# 242  30.7690  -86.9824 1         1      0         NA
# 243  27.3364  -82.5307 1         0      0         NA
# 244  40.7909 -121.8474 1         0      0         NA
# 245  35.1269  -89.9253 1         0      0         NA
# 246  34.8606  -81.9535 1         0      0         NA
# 247  47.6587 -117.4225 1         0      0         NA
# 248  38.6103  -90.4125 1         0      0         NA
# 249  40.9849  -72.6151 1         0      0         NA
# 250  36.1593  -95.9410 1         0      0         NA
# 251  41.8586  -74.3118 1         0      0         NA
# 252  45.7750 -118.7606 1         0      0         NA
# 253  42.4072  -71.3824 1         0      0         NA
# 254  29.0280  -81.0755 1         0      0         NA
# 255  35.8032  -78.5661 1         0      0         NA
# 256  41.6739  -75.2479 1         0      0         NA
# 257  35.9179  -86.8622 1         0      0         NA
# 258  38.7646 -121.9018 1         0      0         NA
# 259  48.3794   31.1656 1         0      0         NA
# 260  41.9029   12.4534 1         0      0         NA
# 261  35.4437  139.6380 0         0      0         NA
# 262 -12.4634  130.8456 0         0      0         17
# 263  29.3829  -98.6134 0         0      0         NA
# 264  30.3213  -95.4778 0         0      0         NA
# 265  41.2545  -95.9758 0         0      0         NA
# 266  38.2721 -121.9399 0         0      0         NA
#     Combined_Key
# 1   Hubei, China
# 2   NA
# 3   NA
# 4   NA
# 5   Guangdong, China
# 6   Henan, China
# 7   Zhejiang, China
# 8   NA
# 9   NA
# 10  NA
# 11  Hunan, China
# 12  Anhui, China
# 13  Jiangxi, China
# 14  Shandong, China
# 15  NA
# 16  Jiangsu, China
# 17  Chongqing, China
# 18  Sichuan, China
# 19  NA
# 20  Heilongjiang, China
# 21  Beijing, China
# 22  NA
# 23  Shanghai, China
# 24  NA
# 25  NA
# 26  Hebei, China
# 27  Fujian, China
# 28  Guangxi, China
# 29  NA
# 30  Shaanxi, China
# ... ...
# 237 NA
# 238 NA
# 239 NA
# 240 NA
# 241 NA
# 242 NA
# 243 NA
# 244 NA
# 245 NA
# 246 NA
# 247 NA
# 248 NA
# 249 NA
# 250 NA
# 251 NA
# 252 NA
# 253 NA
# 254 NA
# 255 NA
# 256 NA
# 257 NA
# 258 NA
# 259 NA
# 260 NA
# 261 NA
# 262 Northern Territory, Australia
# 263 NA
# 264 NA
# 265 NA
# 266 NA

# %%
dbDisconnect(conn)

# %%
library(RSQLite)
library(readr)
library(foreach)

conn <- dbConnect(RSQLite::SQLite(), "CoronaDB.db")
